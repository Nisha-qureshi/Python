# %%
import pandas as pd
df=pd.read_csv("G:/data/h-1b-visa/world-happiness-report-2019.csv")

# %%
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %%
# pd.DataFrame(df[True,False,True,True,False,False,True,True,False,True,False])

# %%
df["Corruption"].max()
# Out:
# 148.0

# %%
df["Corruption"].min()
# Out:
# 1.0

# %%
df.query("Corruption==1.0")
# Out:
#    Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 33        Singapore      34             5             38.0              2.0
#
#     Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 33            36.0     20.0         1.0        21.0                     3.0
#
#     Healthy life\nexpectancy
# 33                       1.0

# %%
df.query("Corruption==148.0")
# Out:
#    Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 70          Moldova      71            45            133.0             67.0
#
#     Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 70            65.0    128.0       148.0        86.0                   109.0
#
#     Healthy life\nexpectancy
# 70                      86.0

# %%
for i in range(1,6):
    c1=df["Generosity"].max()
    print(c1)
# Out:
# 155.0
# 155.0
# 155.0
# 155.0
# 155.0

# %%
#print(df["Freedom"==df["Freedom"].max()])

# %%
df.query("Corruption>135")
# Out:
#             Country (region)  Ladder  SD of Ladder  Positive affect  \
# 37                  Slovakia      38            39             53.0
# 38       Trinidad and Tobago      39            89             14.0
# 45                    Kosovo      46           107             71.0
# 47                   Romania      48            75             80.0
# 61                   Hungary      62            36             86.0
# 70                   Moldova      71            45            133.0
# 74                   Croatia      75            29            122.0
# 77   Bosnia and Herzegovina       78            80            116.0
# 79                  Malaysia      80            12             25.0
# 85                Kyrgyzstan      86            46             58.0
# 96                  Bulgaria      97            47            117.0
# 132                  Ukraine     133            69            131.0
# 153              Afghanistan     154            25            152.0
#
# ...

# %%
plt.hist()
plt.show()
